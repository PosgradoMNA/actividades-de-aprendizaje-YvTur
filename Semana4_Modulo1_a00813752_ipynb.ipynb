# %% [markdown]
# <a href="https://colab.research.google.com/github/PosgradoMNA/actividades-de-aprendizaje-YvTur/blob/main/Semana4_Modulo1_a00813752_ipynb.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Python 101 for Data Science

# %% [markdown]
# ## Module 1 - Introduction

# %% [markdown]
# We are going to center the course related to the following question:
#
# ### **what is the best price for selling a used car?**

# %% [markdown]
# **Scientific Computing Libraries in python**
#
# Pandas- Data Strucutures and tools
#
# Numpy - Arrays & matrices
#
# Scipy - High level math, integrals, differential equations and optimization
#
# **Vizualization**
#
# Matplotlib -  Plots & graphs, most popular
#
# Seaborn    - Plots like heat maps, time series, violin plots
#
#
# **Algorithmic**
#
# Scikit-learn - Machine learning
#
# Statsmodel   - Explore daa, estimate statistical models and perform statistical test

# %% [markdown]
# ###Hands on Lab

# %% [markdown]
# We are going to work on a dataset from the 85 of used car at that time. The job will be learning techniques and methods of pandas to make easier the exploration and understanding of the dataset

# %%
#We first call the pandas library
import pandas as pd
#Note for future Yves, when calling a csv on colab, 
#call it from github and call the raw material
url="https://raw.githubusercontent.com/PosgradoMNA/actividades-de-aprendizaje-YvTur/main/Data%20Analysis/autos_imports-85.csv"

# %%
#We call the url of the CSV
df =pd.read_csv(url)  
#You most remember that pandas can cal a sql, excel,json and CSV

# %%
#Inside the parenthesis of the function you can call more than 5. 
df.head(5)
# Out:
#         %symboling normalized-losses make fuel-type   aspiration num-of-doors  \
# 3 ?    alfa-romero               gas  std       two  convertible          rwd
#   ?    alfa-romero               gas  std       two  convertible          rwd
# 1 ?    alfa-romero               gas  std       two    hatchback          rwd
# 2 164         audi               gas  std      four        sedan          fwd
#   164         audi               gas  std      four        sedan          4wd
#
#       body-style  drive-wheels  wheel-base  length  ...  num-of-cylinders  \
# 3 ?        front          88.6       168.8    64.1  ...               130
#   ?        front          88.6       168.8    64.1  ...               130
# 1 ?        front          94.5       171.2    65.5  ...               152
# 2 164      front          99.8       176.6    66.2  ...               109
#   164      front          99.4       176.6    66.4  ...               136
#
# ...

# %% [markdown]
# **Basic Insights from the data**
#
# It is necessary to check two things:
#
# -Data types
#
# -Data Distribution
#
# The reason to check types is to see if there is any colum that needs to move their type of value to work.

# %%
#we call the types of data of each column and start seeing that some changes will be need it
df.dtypes
# Out:
# %symboling              object
# normalized-losses       object
# make                    object
# fuel-type               object
# aspiration              object
# num-of-doors            object
# body-style              object
# drive-wheels           float64
# wheel-base             float64
# length                 float64
# width                  float64
# height                   int64
# curb-weight             object
# engine-type             object
# num-of-cylinders         int64
# engine-size             object
# fuel-system             object
# bore                    object
# stroke                 float64
# compression-ratio       object
# horsepower-peak-rpm     object
# city-mpg                 int64
# highway-mpg              int64
# price                   object
# dtype: object

# %%
#For knowing general data about your dataframe. You can use the following command
df.describe(include="all")
# Out:
#        %symboling normalized-losses make fuel-type aspiration num-of-doors  \
# count         205               205  205       205        205          205
# unique         22                 2    2         3          5            3
# top        toyota               gas  std      four      sedan          fwd
# freq           32               185  168       114         96          120
# mean          NaN               NaN  NaN       NaN        NaN          NaN
# std           NaN               NaN  NaN       NaN        NaN          NaN
# min           NaN               NaN  NaN       NaN        NaN          NaN
# 25%           NaN               NaN  NaN       NaN        NaN          NaN
# 50%           NaN               NaN  NaN       NaN        NaN          NaN
# 75%           NaN               NaN  NaN       NaN        NaN          NaN
# max           NaN               NaN  NaN       NaN        NaN          NaN
#
#        body-style  drive-wheels  wheel-base      length  ...  \
# ...

# %%
#another way to ssee your top and footer of the dataframe
df.info
# Out:
# <bound method DataFrame.info of          %symboling normalized-losses   make fuel-type   aspiration  \
#  3 ?    alfa-romero               gas    std       two  convertible
#    ?    alfa-romero               gas    std       two  convertible
#  1 ?    alfa-romero               gas    std       two    hatchback
#  2 164         audi               gas    std      four        sedan
#    164         audi               gas    std      four        sedan
# ...             ...               ...    ...       ...          ...
# -1 95         volvo               gas    std      four        sedan
#    95         volvo               gas  turbo      four        sedan
#    95         volvo               gas    std      four        sedan
#    95         volvo            diesel  turbo      four        sedan
#    95         volvo               gas  turbo      four        sedan
#
#        num-of-doors body-style  drive-wheels  wheel-base  length  ...  \
# ...
