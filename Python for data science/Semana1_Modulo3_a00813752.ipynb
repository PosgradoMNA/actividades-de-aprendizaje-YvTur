# %% [markdown]
# <a href="https://colab.research.google.com/github/PosgradoMNA/actividades-de-aprendizaje-YvTur/blob/main/Semana1_Modulo3_a00813752.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Python 101 for Data Science

# %% [markdown]
# ## Module 3 - Programming fundamentals

# %% [markdown]
# **Comparison Operators**
#
# This are similar to boolean operations
#
# Example:
# i=6
#
# i==7
#
# The result wil be false
#
# We can also do
#
# i<7.
#
# This is also true
#
# i!=6   This is false.

# %% [markdown]
# **Branching**
#
# The If statement
#
# You make a declaration to allow or deny the section.
#
# Example:
#
# if (age>18):
#
#   print("you can enter")
#
# else:
#
#   print("go see meat Loaf")
#
# print("move on")

# %%
#In case the age is 17 lets see an example
age=17

if (age>18):
  print("you can enter")
else:
  print("go see meat Loaf")
print("move on")
# Out:
# go see meat Loaf
# move on

# %%
#in case the age is 19 lets see an examle
age=19

if (age>18):
  print("you can enter")
else:
  print("go see meat Loaf")
print("move on")
# Out:
# you can enter
# move on

# %% [markdown]
# **Logic Operators**
#
# You can use the boolean math in python.
#
# Which are:
#
# AND
#
# OR
#
# Not

# %%
#Example of using and in an if statement

album_year=1983
if(album_year>1979) and (album_year<1990):
  print("this album is from the 80s")
# Out:
# this album is from the 80s

# %% [markdown]
# **Range Function**
#
# Examples
#
# Range(3) --> [0,1,2]
#
# Range(10,15)-->[10,11,12,13,14]

# %% [markdown]
# **For Loops**
# The main characteristics of the for loops is that will be conduct an operation for a determine amount of times estabilished

# %%
#In this example we are going to replace the elements of a list
squares=["red","blue","yellow","white","black"]
for i in range(0,5):
  squares[i]="white"
print(squares)
# Out:
# ['white', 'white', 'white', 'white', 'white']

# %%
A=[3,4,5]

for a in A:

  print(a)
# Out:
# 3
# 4
# 5

# %% [markdown]
# **While Loops**
#
# In the case of whiles, they are used when a condition is make it real

# %%
#The following is an example of while loop
i = 1
while i < 6:
  print(i)
  i += 1
# Out:
# 1
# 2
# 3
# 4
# 5

# %% [markdown]
# **Functions**
#
# Are pieces of code that we can just call to reuse in other parts of the code.
#
# Example of a function
#
# def add1 (a):
#
#   b=a+1
#
#   return b

# %%
def add1 (a):
  b=a+1
  return b

add1(5)
# Out:
# 6

# %%
#The funcitons can have multiple parameters
#Following example
def mult(a,b):
  c=a*b
  return c

mult(2,3)
# Out:
# 6

# %%
def f(*x):

  return sum(x)

# %%
f(8)
# Out:
# 8

# %%
print(f)
# Out:
# <function f at 0x7ff8def35e60>

# %% [markdown]
# **Object and Classes**
#
# Each type of data in python is an object.
#
# Every object has a type of data. Integer, float, string, etc.
#
# We can say that when a data assume a type. We called instance of an object, Or also when an object add a type of data, we called instance of type.
#
# The integer is the instance of type int.
#
#
# Methods
# It is also called class or types methods. It is the instance of that class that is provided.
#
# Another form to call a method is that changed the state of the object.
#
# Example

# %%
#The following example is very good to illustrate a point,
#which is that the method reshape the object
list=[3,6,2,8,1,11,5,2]

list.reverse()
print(list)
# Out:
# [2, 5, 11, 1, 8, 2, 6, 3]

# %% [markdown]
# **Creating your own types of Classes**
#
# A class has:
#
# Data Attributes
# Methods
#
# Example of code
#
# Class Rectangle(object)
#
# we define to python that we are creating a class
#
# We bauptize the name of the class
#
# We indicated the parent class.
#
#
# Example Class Circle(object)
# The circle will have raidus and colour
#
# The object circle. THe instance of the class circle. It is blue and has a r=2

# %% [markdown]
# ![python.PNG](data:image/png;base64,...)

# %%
#Example of the class circle
class Circle(object):               #we define our class
#We define the data attributes used to initialize each instance
  def __init__(self,radius,color):   
    self.radius=radius;
    self.color=color;
    #we are going to add a method to our class
    #we are going to add more to the current radius
  def add_radius(self,r):
    self.radius=self.radius+r
    return(self.radius)

# %%
c=Circle(10,'red')

# %%
c.add_radius(8)
# Out:
# 18

# %%
A = ['1','2','3']

for a in A:

  print(2*a)
# Out:
# 11
# 22
# 33
